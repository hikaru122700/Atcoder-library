# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/Atcoder-library/blob/main/santa2024_beam_and_sa_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# このノートブックは以下のノートブックを参考にして作成されました。
#
# この場を借りてノートブックを共有してくださったことに感謝したいと思います。
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# また、以下のノートブックを利用してid4以外の答えを作成しています。ありがとうございます。
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# This notebook was created with reference to the following notebook:
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# I would like to take this opportunity to express my gratitude to the author for sharing their notebook.
#
# Additionally, I used the following notebook to generate answers other than id4. Thank you very much.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# 이 노트북은 다음 노트북을 참고하여 작성되었습니다.
#
# 이 자리를 빌려 노트북을 공유해 주신 것에 대해 감사드립니다.
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# 또한, 아래 노트북을 사용하여 id4 이외의 답변을 작성했습니다. 감사합니다.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# このノートブックはGPU環境下で実行に3時間程度かかります。実行される際は注意してください。
#
# 元ノートブックからの変更点として、ビーム幅を可変にしています。
#
# これにより、重要な局面で多くの情報を残すことができます。

# %% [markdown]
# This notebook takes approximately 3 hours to run in a GPU environment. Please be cautious when executing it.
#
# As a modification from the original notebook, the beam width has been made adjustable.
#
# This allows for retaining more information during critical stages.

# %% [markdown]
# 이 노트북은 GPU 환경에서 실행하는 데 약 3시간 정도 소요됩니다. 실행 시 유의하시기 바랍니다.
#
# 원본 노트북에서의 변경점으로, 빔 폭을 가변적으로 설정하였습니다.
#
# 이를 통해 중요한 국면에서 더 많은 정보를 남길 수 있습니다.

# %%
print("Yes")
# Out:
# Yes

# %%
# !pip install accelerate peft bitsandbytes transformers
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 32.9 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %%
import gc
import os
import time
import math
from math import exp
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch
import heapq
from tqdm import tqdm

import random
import statistics
from collections import Counter
from dataclasses import dataclass
from typing import Any, Callable, List, Optional, Tuple, Union

import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import bitsandbytes
from pprint import pprint

# %%
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class HuggingFaceModelLoader:
    def __init__(self, model_path: str, load_in_8bit: bool, device_map: str):
        self.model_path = model_path
        self.load_in_8bit = load_in_8bit
        self.device_map = device_map

    def load_model(self) -> transformers.PreTrainedModel:
        if self.load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires a CUDA device')

            quantization_config = transformers.BitsAndBytesConfig(
                load_in_4bit=True,
                bnb_4bit_quant_type="fp4",
                bnb_4bit_use_double_quant=False,
                bnb_4bit_compute_dtype=torch.float16,
            )

            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                quantization_config=quantization_config,
                device_map=self.device_map
            )
        else:
            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=self.device_map
            )

        model.eval()
        return model


class HuggingFaceTokenizer:
    def __init__(self, model_path: str):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path, padding_side="right")
        self.bos_token = self.tokenizer.bos_token or self.tokenizer.cls_token
        self.eos_token = self.tokenizer.eos_token or self.tokenizer.sep_token
        if self.bos_token is None:
            self.bos_token = ""
        if self.eos_token is None:
            self.eos_token = ""

    def tokenize(self, texts: List[str]) -> dict:
        processed_texts = []

        for text in texts:
            combined_text = f"{self.bos_token}{text}{self.eos_token}"
            processed_texts.append(combined_text)

        model_inputs = self.tokenizer(
            processed_texts,
            return_tensors='pt',
            add_special_tokens=False,
            padding=True
        )

        if 'token_type_ids' in model_inputs:
            model_inputs.pop('token_type_ids')

        return model_inputs


class PerplexityCalculator:
    def __init__(self, model_loader, tokenizer, exp_mode=False):
        self.model = model_loader.load_model()
        self.tokenizer = tokenizer
        self.exp_mode = exp_mode
        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

    def get_perplexity(
        self,
        input_texts: Union[str, List[str]],
        batch_size: int = 32
    ) -> Union[float, List[float]]:

        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        num_texts = len(input_texts)
        batches = num_texts // batch_size + (num_texts % batch_size != 0)
        with torch.no_grad():
            for j in range(batches):
                start_idx = j * batch_size
                end_idx = (j + 1) * batch_size
                input_batch = input_texts[start_idx:end_idx]

                with torch.no_grad():
                    model_inputs = self.tokenizer.tokenize(input_batch)
                    model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

                    output = self.model(**model_inputs, use_cache=False)
                    logits = output['logits']

                    label = model_inputs['input_ids']
                    if hasattr(self.model.config, 'pad_token_id') and self.model.config.pad_token_id is not None:
                        label[label == self.model.config.pad_token_id] = PAD_TOKEN_LABEL_ID

                    shift_logits = logits[..., :-1, :].contiguous()
                    shift_labels = label[..., 1:].contiguous()

                    token_loss = self.loss_fct(
                        shift_logits.view(-1, shift_logits.size(-1)),
                        shift_labels.view(-1)
                    ).view(len(logits), -1)

                    valid_length = (shift_labels != PAD_TOKEN_LABEL_ID).sum(dim=-1)
                    sequence_loss = torch.sum(token_loss, -1) / valid_length
                    loss_list.extend(sequence_loss.cpu().tolist())

        if self.exp_mode:
            ppl = [exp(i) for i in loss_list]
        else:
            ppl = loss_list

        return ppl[0] if single_input else ppl

# %%
import os
from google.colab import userdata
import os

# Hugging Faceのトークンを環境変数に設定
os.environ["HF_TOKEN"] = "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"

# %%
from huggingface_hub import HfApi, hf_hub_download
import os
from multiprocessing import Pool

# Specify your model repository
model_name = "google/gemma-2-9b"

# Create a directory to store the downloaded model files
download_dir = "/content/model"
os.makedirs(download_dir, exist_ok=True)

# Initialize API
api = HfApi()

# Get the list of all files in the repository
files = api.list_repo_files(model_name)

# **Your Hugging Face token**
hf_token = "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"  # ここにあなたのHugging Faceトークンを入力してください

def download_file(file_path):
    try:
        # Download each file to the specified directory with token
        hf_hub_download(
            repo_id=model_name,
            filename=file_path,
            local_dir=download_dir,
            token=hf_token
        )
        print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Error downloading {file_path}: {e}")

# Use multiprocessing to download files in parallel
if __name__ == "__main__":
    with Pool(processes=8) as pool:  # Adjust the number of processes based on Colab limits
        pool.map(download_file, files)
# Out:
# Downloaded config.json
# Downloaded generation_config.json
# Downloaded README.md
# model-00005-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Downloaded .gitattributes
# model-00006-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/2.38G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Downloaded model-00008-of-00008.safetensors
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# Downloaded model.safetensors.index.json
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloaded special_tokens_map.json
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Downloaded tokenizer.json
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# Downloaded tokenizer.model
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# Downloaded tokenizer_config.json
# (…)ransformers-4.42.0.dev0-py3-none-any.whl:   0%|          | 0.00/9.21M [00:00<?, ?B/s]
# Downloaded transformers/transformers-4.42.0.dev0-py3-none-any.whl
# Downloaded model-00001-of-00008.safetensors
# Downloaded model-00003-of-00008.safetensors
# Downloaded model-00002-of-00008.safetensors
# Downloaded model-00005-of-00008.safetensors
# Downloaded model-00004-of-00008.safetensors
# Downloaded model-00006-of-00008.safetensors
# Downloaded model-00007-of-00008.safetensors

# %%
model_path = "/content/model"
model_loader = HuggingFaceModelLoader(model_path=model_path, load_in_8bit=False, device_map='auto')
tokenizer = HuggingFaceTokenizer(model_path)
scorer = PerplexityCalculator(model_loader, tokenizer, exp_mode=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
class BeamSearch:
    def __init__(self, beam_width, scorer: PerplexityCalculator):
        self.beam_width = beam_width
        self.scorer = scorer

    def _make_candidates_adding_word(self, intermediate_solution, words):
        """
        Make candidate text so that word duplication does not occur
        """
        candidates = []
        not_used_words = words.copy()

        for used_word in intermediate_solution.split():
            if used_word in not_used_words:
                not_used_words.remove(used_word)

        # Generate candidates by adding unused words to the end
        candidates += [(intermediate_solution + ' ' + word).strip() for word in not_used_words]

        # Generate candidates by adding unused words to the beginning
        candidates += [(word + ' ' + intermediate_solution).strip() for word in not_used_words]

        # Remove duplicates
        candidates = list(set(candidates))

        return candidates

    def _select_new_intermediate_solutions(self, scored_candidates):
        """
        Select top candidates based on beam width while ensuring diversity.
        Include candidates with scores within a diversity threshold (e.g., 1.1 times the best score).
        """

        # Best (lowest) score among all candidates
        best_score = scored_candidates[0][0]

        # To track unique candidates and their scores
        seen = set()
        new_intermediate_solutions = []
        selected_scores = []

        for score, candidate in scored_candidates:
            if candidate in seen:
                continue

            # Add candidate if it meets the diversity threshold
            if score > 1.1 * best_score:
                break  # Stop adding candidates if diversity threshold is exceeded

            # Add the candidate and its score
            new_intermediate_solutions.append(candidate)
            selected_scores.append(score)
            seen.add(candidate)

            # Stop when beam width is reached
            if len(new_intermediate_solutions) >= self.beam_width:
                break

        return new_intermediate_solutions, selected_scores

    def _print_progress(self, intermediate_solutions, current_scores, start_time, words):
        """
        Print progress during the beam search process.
        """
        # Best (lowest) score in current iteration
        best_score = exp(min(current_scores))

        # Count of used and remaining words
        used_word_count = len(intermediate_solutions[0].split())
        remaining_word_count = len(words) - used_word_count

        # Time elapsed for this iteration
        elapsed = time.time() - start_time
        estimated_remaining_time = remaining_word_count * elapsed

        # Print progress
        print("===== Beam Search Progress =====")
        print(f"Best Score (Perplexity): {best_score:.4f}")
        print(f"Intermediate Solutions: {intermediate_solutions}")
        print(f"Words Processed: {used_word_count}/{len(words)}")
        print(f"Estimated Remaining Time: {estimated_remaining_time:.2f} seconds")
        print("================================\n")

    def solve(self, text, batch_size=32):
        words = text.split()
        intermediate_solutions = ['']
        eval_cnt = 0

        # Loop until all words are used in the intermediate solution
        while len(intermediate_solutions[0].split()) < len(words):
            start_time = time.time()
            candidates = []

            for intermediate_solution in intermediate_solutions:
                new_candidates = self._make_candidates_adding_word(intermediate_solution, words)
                for candidate in new_candidates:
                    candidates.append(candidate)

           # Remove duplicate candidates
            candidates = list(set(candidates))
            scores = self.scorer.get_perplexity(candidates, batch_size=batch_size)

            eval_cnt += len(scores)
            scored_candidates = sorted(zip(scores, candidates), key=lambda x: x[0] )

            intermediate_solutions, current_scores = self._select_new_intermediate_solutions(scored_candidates)

            self._print_progress(intermediate_solutions, current_scores, start_time, words)

        return current_scores, intermediate_solutions, eval_cnt

# %%
params = {
    'beam_width': 20,
    'scorer': scorer
}
optimizer = BeamSearch(**params)

# %%
Score = float
Solution = str

# Timer start
start_time = time.time()

# Initialize lists to store results
scores: List[Score] = []
solutions: List[Solution] = []
eval_cnts: List[int] = []

'''
The following code is executed only once.
Since my beam search does not involve randomness, running it multiple times will not produce new solutions.

아래 코드는 한 번만 실행됩니다.
제 빔 서치는 무작위성이 없기 때문에 몇 번 실행해도 새로운 해답이 생성되지 않습니다.
'''
text: str = "sleigh of the magi yuletide cheer is unwrap gifts relax and eat cheer decorations carol sing chimney visit workshop grinch holiday holly jingle naughty nice nutcracker polar beard ornament stocking"
score_results, solution_results, eval_cnt = optimizer.solve(text, batch_size=10)  #
scores.extend(score_results)
solutions.extend(solution_results)
eval_cnts.append(eval_cnt)

# Print the results
print("Scores:", [exp(i) for i in scores])
print("Solutions:", solutions)
print("Evaluation Counts:", eval_cnts)

# Measure and print execution time
execute_time: float = time.time() - start_time
print(f"Execution Time: {execute_time:.2f} seconds")
# Out:
# ===== Beam Search Progress =====
# Best Score (Perplexity): 9110.5421
# Intermediate Solutions: ['yuletide']
# Words Processed: 1/30
# Estimated Remaining Time: 161.35 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 1338.3847
# Intermediate Solutions: ['ornament yuletide', 'sleigh yuletide', 'jingle yuletide', 'magi yuletide']
# Words Processed: 2/30
# Estimated Remaining Time: 210.21 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 629.7434
# Intermediate Solutions: ['ornament yuletide holiday', 'ornament yuletide decorations', 'ornament yuletide nutcracker', 'ornament yuletide unwrap', 'ornament yuletide gifts', 'ornament yuletide holly', 'sleigh yuletide holiday', 'ornament yuletide of']
# Words Processed: 3/30
# Estimated Remaining Time: 743.18 seconds
# ================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-370f87bdae63> in <cell line: 20>()
#      18 '''
#      19 text: str = "sleigh of the magi yuletide cheer is unwrap gifts relax and eat cheer decorations carol sing chimney visit workshop grinch holiday holly jingle naughty nice nutcracker polar beard ornament stocking"
# ---> 20 score_results, solution_results, eval_cnt = optimizer.solve(text, batch_size=10)  #
#      21 scores.extend(score_results)
#      22 solutions.extend(solution_results)
#
# <ipython-input-8-859854b1afe9> in solve(self, text, batch_size)
#      99            # Remove duplicate candidates
#     100             candidates = list(set(candidates))
# --> 101             scores = self.scorer.get_perplexity(candidates, batch_size=batch_size)
#     102
#     103             eval_cnt += len(scores)
#
# <ipython-input-4-1524a24b63b0> in get_perplexity(self, input_texts, batch_size)
#      98                     model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}
#      99
# --> 100                     output = self.model(**model_inputs, use_cache=False)
#     101                     logits = output['logits']
#     102
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#     975         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     976         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 977         outputs = self.model(
#     978             input_ids=input_ids,
#     979             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     761                 )
#     762             else:
# --> 763                 layer_outputs = decoder_layer(
#     764                     hidden_states,
#     765                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     491         residual = hidden_states
#     492         hidden_states = self.pre_feedforward_layernorm(hidden_states)
# --> 493         hidden_states = self.mlp(hidden_states)
#     494         hidden_states = self.post_feedforward_layernorm(hidden_states)
#     495         hidden_states = residual + hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, x)
#      93
#      94     def forward(self, x):
# ---> 95         return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#      96
#      97
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     163
#     164     def new_forward(module, *args, **kwargs):
# --> 165         args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     166         if module._hf_hook.no_grad:
#     167             with torch.no_grad():
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in pre_forward(self, module, *args, **kwargs)
#     353                     self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
#     354
# --> 355                 set_module_tensor_to_device(
#     356                     module,
#     357                     name,
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/modeling.py in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     327                     module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     328         elif isinstance(value, torch.Tensor):
# --> 329             new_value = value.to(device)
#     330         else:
#     331             new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:

# %%
solutions = ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax']

# %%
import random
from typing import List

class TSPListOperations:
    @staticmethod
    def two_rotation(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()
        i, j = random.sample(range(len(item)), 2)
        # 2つの要素を交換（i, j）→（j, i）
        new_item = item.copy()
        new_item[i], new_item[j] = new_item[j], new_item[i]
        return new_item

    @staticmethod
    def random_rotation(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()

        start_idx, end_idx = sorted(random.sample(range(len(item)), 2))

        shift = random.randint(1, len(item) - 1)
        sublist = item[start_idx:end_idx + 1]

        shift = shift % len(sublist)  # シフトをサブリストの長さ内に正規化
        rotated_sublist = sublist[shift:] + sublist[:shift]

        new_item = item.copy()
        new_item[start_idx:end_idx + 1] = rotated_sublist

        return new_item

    @staticmethod
    def random_insertion(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()

        size = random.randint(2, min(8, len(item)))
        if len(item) - size <= 0:
            start = 0
        else:
            start = random.randint(0, len(item) - size)
        end = start + size

        sublist = item[start:end]
        new_item = item.copy()
        del new_item[start:end]

        if random.random() < 0.5:
            insert_pos = random.randint(0, len(new_item))
            new_item[insert_pos:insert_pos] = sublist
        else:
            insert_pos = random.randint(0, len(new_item))
            new_item[insert_pos:insert_pos] = sublist[::-1]  # サブリストを逆順にして挿入

        return new_item

    @staticmethod
    def shuffle_sublist(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()

        size = random.randint(2, min(8, len(item)))
        if len(item) - size <= 0:
            start = 0
        else:
            start = random.randint(0, len(item) - size)
        end = start + size
        sublist = item[start:end]
        random.shuffle(sublist)
        new_item = item.copy()
        new_item[start:end] = sublist
        return new_item

    @staticmethod
    def double_bridge_move(item: List[str]) -> List[str]:
        n = len(item)
        if n < 8:
            # ダブルブリッジ移動は大きなリストでより効果的
            return TSPListOperations.random_insertion(item)

        # ツアーを4つのセグメントに分割
        indices = sorted(random.sample(range(1, n - 1), 3))
        a, b, c = indices
        A = item[:a]
        B = item[a:b]
        C = item[b:c]
        D = item[c:]

        # セグメントを異なる順序で再接続
        if random.choice([True, False]):
            B = B[::-1]
        if random.choice([True, False]):
            D = D[::-1]

        new_item = A + D + C + B
        return new_item

    @staticmethod
    def inversion(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()
        start, end = sorted(random.sample(range(len(item)), 2))
        new_item = item.copy()
        new_item[start:end + 1] = new_item[start:end + 1][::-1]
        return new_item

    @staticmethod
    def scramble(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()
        start, end = sorted(random.sample(range(len(item)), 2))
        new_item = item.copy()
        sublist = new_item[start:end + 1]
        random.shuffle(sublist)
        new_item[start:end + 1] = sublist
        return new_item
    def three_opt_move(item: List[str]) -> List[str]:
        n = len(item)
        if n < 6:
            # 3-opt 移動には最低でも6つのノードが必要
            return item.copy()

        # 3つの異なるインデックスを選択
        indices = sorted(random.sample(range(n), 3))
        i, j, k = indices

        # セグメントの分割
        A = item[:i]
        B = item[i:j]
        C = item[j:k]
        D = item[k:]

        # いくつかの再接続パターンからランダムに選択
        reconnections = [
            A + B[::-1] + C + D,
            A + B + C[::-1] + D,
            A + C + B + D,
            A + C[::-1] + B[::-1] + D,
            A + B[::-1] + C[::-1] + D,
        ]
        new_item = random.choice(reconnections)
        return new_item

def neighbor_fn(arr: str, prefix: int = 0, suffix: int = 0) -> str:
    item = arr.split()
    operations = [
        TSPListOperations.two_rotation,
        TSPListOperations.random_rotation,
        TSPListOperations.random_insertion,
        TSPListOperations.shuffle_sublist,
        TSPListOperations.double_bridge_move,
        TSPListOperations.inversion,
        TSPListOperations.scramble,
        TSPListOperations.three_opt_move,
    ]


    op = random.choice(operations)
    item_modified = item[:prefix] + op(item[prefix:len(item)-suffix]) + item[len(item)-suffix:]
    return ' '.join(item_modified)

# %%
class SimulatedAnnealing:
    def __init__(self, start_temp, end_temp, max_iterations, cost_fn, neighbor_fn, random_state):
        self.start_temp = start_temp
        self.end_temp = end_temp
        self.max_iterations = max_iterations
        self.cost_fn = cost_fn
        self.neighbor_fn = neighbor_fn
        random.seed(random_state)

    def _acceptance_probability(self, diff, temperature):
        if diff <= 0:
            return 1.0
        return exp(-diff/temperature)

    def _lower_temperature(self, temperature, iteration):
        t1 = self.end_temp + self.start_temp/(1 + math.log(iteration+1))
        t2 = self.start_temp + (self.end_temp - self.start_temp)*(iteration/self.max_iterations)
        return max(t1, t2)

    def _print_progress(
        self,
        iteration: int,
        best_solutions: List[List[str]],
        best_energies: List[float],
        current_solutions: List[List[str]],
        current_energies: List[float],
        temperature: float,
        start_time: float,
        spend_minute: int
    ) -> int:
        current_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        elapsed_time = time.time() - start_time
        Estimated_remaining_execution_time = (elapsed_time / (iteration+1)) * (self.max_iterations - iteration)

        # Check if 60 seconds have passed since the last update
        if elapsed_time - 60 * spend_minute > 60:
            spend_minute += 1
            progress = iteration / self.max_iterations * 100  # Progress as percentage

            # Print progress in a structured format
            print("===== Simulated Annealing Progress =====")
            print(f"Time: {current_time}")
            print(f"Iteration: {iteration}/{self.max_iterations} ({progress:.2f}%)")
            print(f"Temperature: {temperature:.4f}")
            print(f"Elapsed Time: {elapsed_time:.2f} seconds")
            print(f"Estimated_remaining_execution_time: {(Estimated_remaining_execution_time//60):.2f} minutes")


            # Print best solutions and energies
            print("\nBest Solutions:")
            idx_items = np.argsort(best_energies)[:5]

            for i, idx in enumerate(idx_items):
                print(f"  Solution {i+1}: {best_solutions[idx]}")
            print("\nBest Energies:")
            print("  " + ", ".join(f"{best_energies[idx]:.4f}" for idx in idx_items))

            # Print current solutions and energies
            print("\nCurrent Solutions:")
            for i, solution in enumerate(current_solutions[:5]):
                print(f"  Solution {i+1}: {solution}")
            print("\nCurrent Energies:")
            print("  " + ", ".join(f"{energy:.4f}" for energy in current_energies[:5]))

            print("========================================\n")

        return spend_minute


    def solve_batch(self, text_list, max_minute=180):
        """
        Perform Simulated Annealing for multiple texts at once.
        """
        solutions = text_list[:]
        current_energies = self.cost_fn(solutions)

        best_solutions = solutions[:]
        best_energies = current_energies[:]

        log_energies = [[] for _ in range(len(text_list))]
        for i in range(len(text_list)):
            log_energies[i].append(current_energies[i])

        temperature = self.start_temp
        start_time = time.time()
        spend_minute = 0

        for iteration in range(self.max_iterations):
            # 1) Generate neighbors
            new_solutions = [self.neighbor_fn(sol) for sol in solutions]

            # 2) Calculate new energies in batch
            new_energies = self.cost_fn(new_solutions)

            # 3) Acceptance and update
            for i in range(len(text_list)):

                diff = new_energies[i] - current_energies[i]
                ap = self._acceptance_probability(diff, temperature)

                if random.random() < ap:
                    solutions[i] = new_solutions[i]
                    current_energies[i] = new_energies[i]

                if current_energies[i] < best_energies[i]:
                    best_solutions[i] = solutions[i][:]
                    best_energies[i] = current_energies[i]

            # 4) Lower temperature
            temperature = self._lower_temperature(temperature, iteration)

            # 5) Log current energies
            for i in range(len(text_list)):
                log_energies[i].append(current_energies[i])

            # 6) Print progress (extracted into separate method)
            spend_minute = self._print_progress(
                iteration,
                best_solutions,
                best_energies,
                solutions,
                current_energies,
                temperature,
                start_time,
                spend_minute
            )

            # 7) Early stop if temperature is below threshold
            if temperature <= self.end_temp or spend_minute >= max_minute:
                print("Exiting.")
                break

        print(f"Execution time: {time.time() - start_time:.4f}s")

        # Convert best solutions back to strings
        return best_solutions, best_energies, log_energies

# %%
def cost_fn(sol):
    return scorer.get_perplexity(sol, batch_size=20)

# %%
torch.cuda.empty_cache()

# %%
sa_params = {
    'start_temp': 0.03,             # Initial temperature
    'end_temp': 0.003,          # Final temperature, decreasing linearly
    'max_iterations': 4500,    #45000 Number of iterations (approximately 4 hours for 100,000 iterations)
    'random_state': 42,          # Seed for the random number generator to ensure reproducibility
    # "alpha": 0.9999,             # Exponential decay rate for temperature reduction
    "cost_fn": cost_fn,
    "neighbor_fn": neighbor_fn
}

# Initialize the SimulatedAnnealing optimizer with the specified parameters
sa_optimizer = SimulatedAnnealing(**sa_params)

# %%
solutions
# Out:
# ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax']

# %%
best_solutions, best_energies, log_scores = sa_optimizer.solve_batch(solutions)
# Out:
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:45:12
# Iteration: 33/4500 (0.73%)
# Temperature: 0.0298
# Elapsed Time: 61.75 seconds
# Estimated_remaining_execution_time: 8112.97 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi
#   Solution 3: ornament yuletide holiday gifts magi decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit and workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi
#
# Best Energies:
#   6.0742, 6.1328, 6.1406, 6.1484, 6.1719
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly magi sleigh polar beard cheer cheer is unwrap relax eat visit workshop sing jingle
#   Solution 3: ornament yuletide holiday gifts magi decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit and workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#
# Current Energies:
#   6.1328, 6.1875, 6.1406, 6.1719, 6.0742
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:46:12
# Iteration: 66/4500 (1.47%)
# Temperature: 0.0296
# Elapsed Time: 121.71 seconds
# Estimated_remaining_execution_time: 8054.91 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 4: ornament yuletide holiday gifts magi decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit and workshop
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#
# Best Energies:
#   6.0742, 6.1328, 6.1367, 6.1406, 6.1484
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly magi sleigh polar beard cheer cheer is unwrap relax eat visit workshop sing jingle
#   Solution 3: ornament yuletide holiday gifts magi decorations of the nutcracker carol grinch holly naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit and workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice polar beard visit chimney stocking holly jingle sleigh workshop magi
#
# Current Energies:
#   6.1328, 6.1875, 6.1953, 6.1367, 6.1211
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:47:12
# Iteration: 99/4500 (2.20%)
# Temperature: 0.0294
# Elapsed Time: 181.59 seconds
# Estimated_remaining_execution_time: 7991.58 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 4: ornament yuletide holiday gifts magi decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit and workshop
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#
# Best Energies:
#   6.0430, 6.0742, 6.1367, 6.1406, 6.1484
#
# Current Solutions:
#   Solution 1: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney magi holly stocking sleigh polar beard cheer cheer is unwrap relax eat visit workshop sing jingle
#   Solution 3: ornament yuletide of decorations holiday magi gifts the nutcracker carol grinch holly naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing and workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice polar beard visit chimney stocking holly jingle sleigh workshop magi
#
# Current Energies:
#   6.0430, 6.2070, 6.2227, 6.1367, 6.1211
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:48:12
# Iteration: 132/4500 (2.93%)
# Temperature: 0.0292
# Elapsed Time: 241.54 seconds
# Estimated_remaining_execution_time: 7932.64 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 3: ornament yuletide of decorations holiday gifts the magi grinch carol holly naughty nice nutcracker chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing and workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#
# Best Energies:
#   6.0430, 6.0742, 6.1250, 6.1367, 6.1484
#
# Current Solutions:
#   Solution 1: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide of the nutcracker carol grinch naughty nice chimney magi holly stocking sleigh polar beard decorations and gifts holiday cheer cheer is unwrap relax eat visit workshop sing jingle
#   Solution 3: ornament yuletide of decorations holiday gifts the magi grinch carol holly naughty nice nutcracker chimney stocking jingle sleigh polar beard is unwrap eat relax visit cheer cheer sing and workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit chimney workshop eat relax sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice visit chimney stocking holly jingle workshop sleigh magi polar beard
#
# Current Energies:
#   6.0430, 6.2383, 6.1758, 6.1562, 6.1406
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:49:12
# Iteration: 165/4500 (3.67%)
# Temperature: 0.0290
# Elapsed Time: 301.68 seconds
# Estimated_remaining_execution_time: 7878.23 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 3: ornament yuletide chimney holiday gifts magi naughty and nice stocking decorations of the nutcracker carol grinch holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 4: ornament yuletide of decorations holiday gifts the magi grinch carol holly naughty nice nutcracker chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing and workshop
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#
# Best Energies:
#   6.0352, 6.0742, 6.1133, 6.1250, 6.1367
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide of the nutcracker carol grinch naughty nice chimney magi holly stocking sleigh polar beard decorations and gifts holiday cheer cheer is unwrap relax eat visit workshop sing jingle
#   Solution 3: ornament yuletide of decorations holiday gifts the magi grinch carol holly naughty nice nutcracker sleigh polar beard is unwrap eat relax visit cheer sing and workshop chimney stocking jingle cheer
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit chimney workshop eat relax sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice visit chimney sleigh workshop jingle holly stocking magi polar beard
#
# Current Energies:
#   6.0352, 6.2383, 6.2266, 6.1562, 6.1367
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:50:12
# Iteration: 198/4500 (4.40%)
# Temperature: 0.0288
# Elapsed Time: 361.42 seconds
# Estimated_remaining_execution_time: 7813.15 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 3: ornament yuletide holiday unwrap gifts magi workshop grinch carol the nutcracker naughty nice chimney stocking holly jingle sleigh polar beard eat sing visit relax and of decorations cheer cheer is
#   Solution 4: ornament yuletide chimney holiday gifts magi naughty and nice stocking decorations of the nutcracker carol grinch holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#
# Best Energies:
#   6.0352, 6.0742, 6.0742, 6.1133, 6.1250
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide of the nutcracker carol grinch naughty nice magi holly chimney stocking sleigh polar beard gifts holiday cheer cheer is unwrap relax eat decorations and visit workshop sing jingle
#   Solution 3: ornament yuletide of holiday gifts the magi carol grinch is naughty nice nutcracker sleigh polar beard holly unwrap eat relax cheer decorations sing and workshop chimney stocking visit jingle cheer
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax grinch carol nutcracker naughty nice visit chimney sleigh workshop jingle holly stocking magi polar beard
#
# Current Energies:
#   6.0352, 6.3125, 6.2734, 6.1250, 6.1406
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:51:12
# Iteration: 231/4500 (5.13%)
# Temperature: 0.0286
# Elapsed Time: 421.23 seconds
# Estimated_remaining_execution_time: 7751.08 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat sing relax nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard visit workshop magi
#   Solution 3: ornament yuletide holiday unwrap gifts magi workshop grinch carol the nutcracker naughty nice chimney stocking holly jingle sleigh polar beard eat sing visit relax and of decorations cheer cheer is
#   Solution 4: ornament yuletide chimney holiday gifts magi naughty and nice stocking decorations of the nutcracker carol grinch holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#
# Best Energies:
#   6.0352, 6.0742, 6.0742, 6.1133, 6.1250
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly sleigh polar beard is unwrap cheer eat cheer sing jingle relax visit workshop
#   Solution 2: ornament yuletide grinch naughty nice of the nutcracker magi carol holly chimney stocking sleigh polar beard gifts holiday cheer cheer is unwrap relax eat decorations and visit workshop sing jingle
#   Solution 3: ornament yuletide of holiday gifts magi carol the grinch is naughty nice nutcracker sleigh polar beard holly unwrap eat relax cheer decorations sing and workshop chimney stocking visit jingle cheer
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop jingle holly stocking magi polar beard
#
# Current Energies:
#   6.1406, 6.2539, 6.2852, 6.1250, 6.0859
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:52:12
# Iteration: 264/4500 (5.87%)
# Temperature: 0.0284
# Elapsed Time: 481.02 seconds
# Estimated_remaining_execution_time: 7688.98 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 2: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#   Solution 3: ornament yuletide holiday unwrap gifts magi workshop grinch carol the nutcracker naughty nice chimney stocking holly jingle sleigh polar beard eat sing visit relax and of decorations cheer cheer is
#   Solution 4: ornament yuletide chimney holiday gifts magi naughty and nice stocking decorations of the nutcracker carol grinch holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#
# Best Energies:
#   6.0352, 6.0586, 6.0742, 6.1133, 6.1250
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly sleigh polar beard is unwrap cheer eat cheer sing jingle relax visit workshop
#   Solution 2: ornament yuletide grinch naughty nice of the nutcracker magi chimney stocking sleigh polar beard gifts holiday cheer cheer is unwrap relax eat decorations and visit workshop sing carol holly jingle
#   Solution 3: ornament yuletide of holiday gifts magi carol the grinch is naughty nice nutcracker sleigh polar beard holly unwrap eat relax cheer decorations sing and workshop chimney stocking visit jingle cheer
#   Solution 4: ornament yuletide holiday decorations and nutcracker carol gifts of the magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty visit nice chimney sleigh workshop magi polar beard stocking holly jingle
#
# Current Energies:
#   6.1406, 6.2422, 6.2852, 6.1484, 6.1484
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:53:12
# Iteration: 297/4500 (6.60%)
# Temperature: 0.0282
# Elapsed Time: 540.82 seconds
# Estimated_remaining_execution_time: 7627.68 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 2: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 3: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#   Solution 4: ornament yuletide holiday unwrap gifts magi workshop grinch carol the nutcracker naughty nice chimney stocking holly jingle sleigh polar beard eat sing visit relax and of decorations cheer cheer is
#   Solution 5: ornament yuletide nutcracker carol magi gifts and decorations of eat relax sing visit workshop the grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap holiday
#
# Best Energies:
#   5.9453, 6.0352, 6.0586, 6.0742, 6.1094
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday carol holly decorations of the magi gifts grinch naughty nice nutcracker chimney stocking and sleigh polar is beard unwrap cheer eat cheer sing jingle relax visit workshop
#   Solution 2: ornament yuletide grinch naughty nice of the nutcracker magi chimney stocking sleigh polar beard gifts holiday cheer cheer is unwrap relax eat decorations and visit workshop sing carol holly jingle
#   Solution 3: ornament yuletide of holiday gifts magi carol grinch the is naughty nice nutcracker sleigh polar beard holly unwrap eat relax cheer decorations sing and workshop chimney visit jingle cheer stocking
#   Solution 4: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#
# Current Energies:
#   6.1406, 6.2422, 6.3359, 5.9453, 6.0586
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:54:11
# Iteration: 330/4500 (7.33%)
# Temperature: 0.0280
# Elapsed Time: 600.64 seconds
# Estimated_remaining_execution_time: 7566.98 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 2: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 3: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#   Solution 4: magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer is cheer unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday unwrap gifts magi workshop grinch carol the nutcracker naughty nice chimney stocking holly jingle sleigh polar beard eat sing visit relax and of decorations cheer cheer is
#
# Best Energies:
#   5.9453, 6.0352, 6.0586, 6.0703, 6.0742
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker chimney stocking and visit workshop sleigh polar is beard carol sing jingle relax unwrap cheer eat cheer holly
#   Solution 2: ornament yuletide grinch naughty nice of the nutcracker magi chimney stocking sleigh polar beard gifts cheer holiday cheer is unwrap relax eat decorations and visit workshop sing carol holly jingle
#   Solution 3: ornament yuletide of holiday the magi carol grinch gifts is naughty nice nutcracker sleigh polar beard holly unwrap eat relax cheer decorations sing and workshop chimney visit jingle cheer stocking
#   Solution 4: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker magi polar beard stocking naughty nice visit chimney workshop sleigh holly jingle
#
# Current Energies:
#   6.0820, 6.2617, 6.3047, 5.9453, 6.1133
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 08:55:11
# Iteration: 363/4500 (8.07%)
# Temperature: 0.0278
# Elapsed Time: 660.47 seconds
# Estimated_remaining_execution_time: 7506.46 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 2: ornament yuletide holiday and decorations of the magi gifts nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop
#   Solution 3: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#   Solution 4
ocking
#   Solution 4: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop and relax eat jingle sing sleigh polar beard is cheer cheer holiday decorations unwrap stocking chimney holly
#   Solution 5: ornament yuletide holiday decorations and the gifts of cheer cheer is unwrap eat grinch sing carol nutcracker relax holly jingle workshop magi polar beard stocking naughty nice visit chimney sleigh
#
# Current Energies:
#   5.9609, 6.4336, 6.2422, 6.1836, 6.0938
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 09:01:12
# Iteration: 562/4500 (12.49%)
# Temperature: 0.0266
# Elapsed Time: 1021.24 seconds
# Estimated_remaining_execution_time: 7143.25 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 2: ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker polar workshop visit sleigh stocking and chimney is beard carol sing jingle relax unwrap eat cheer cheer holly
#   Solution 3: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#   Solution 4: magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer is cheer unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday unwrap gifts magi workshop grinch carol the nutcracker naughty nice chimney stocking holly jingle sleigh polar beard eat sing visit relax and of decorations cheer cheer is
#
# Best Energies:
#   5.9453, 5.9609, 6.0586, 6.0703, 6.0742
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker polar workshop visit sleigh stocking and chimney is beard carol sing jingle relax unwrap eat cheer cheer holly
#   Solution 2: ornament yuletide grinch the nutcracker magi holiday carol cheer gifts decorations holly cheer naughty nice of is unwrap relax eat sleigh polar beard jingle and visit workshop stocking chimney sing
#   Solution 3: ornament yuletide of the magi carol grinch polar beard holly sleigh workshop chimney visit naughty is nice sing jingle gifts unwrap and cheer relax decorations cheer eat holiday nutcracker stocking
#   Solution 4: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop and relax eat jingle sing sleigh polar unwrap decorations holiday cheer cheer is beard holly chimney stocking
#   Solution 5: ornament yuletide holiday decorations and the gifts of cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney holly jingle workshop magi polar beard stocking sleigh
#
# Current Energies:
#   5.9609, 6.3906, 6.2617, 6.1758, 6.1406
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 09:02:12
# Iteration: 595/4500 (13.22%)
# Temperature: 0.0264
# Elapsed Time: 1081.14 seconds
# Estimated_remaining_execution_time: 7083.64 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 2: ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker polar workshop visit sleigh stocking and chimney is beard carol sing jingle relax unwrap eat cheer cheer holly
#   Solution 3: ornament yuletide holiday gifts and decorations of the cheer cheer is unwrap eat grinch sing carol relax nutcracker naughty nice visit chimney sleigh workshop magi polar beard stocking holly jingle
#   Solution 4: ornament yuletide holiday gifts and decorations unwrap eat sing visit workshop relax cheer grinch carol magi nutcracker polar beard naughty nice chimney stocking holly jingle sleigh is the of cheer
#   Solution 5: ornament yuletide holiday gifts and decorations nutcracker of the magi carol grinch unwrap relax visit workshop eat sing chimney stocking naughty nice holly jingle sleigh polar beard cheer is cheer
#
# Best Energies:
#   5.9453, 5.9609, 6.0586, 6.0625, 6.0664
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker polar workshop visit sleigh stocking and chimney is beard carol sing jingle relax unwrap holly eat cheer cheer
#   Solution 2: ornament yuletide grinch the nutcracker magi holiday carol cheer gifts decorations holly cheer naughty nice of is unwrap relax and jingle eat sleigh polar beard visit workshop stocking chimney sing
#   Solution 3: ornament yuletide of the magi carol grinch polar beard holly sleigh workshop chimney visit naughty nice is cheer jingle gifts unwrap and cheer eat sing relax decorations holiday nutcracker stocking
#   Solution 4: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit unwrap cheer cheer holiday decorations workshop relax and eat jingle sing sleigh polar is beard holly chimney stocking
#   Solution 5: ornament yuletide holiday decorations and the gifts of cheer cheer is unwrap eat relax grinch sing carol nutcracker naughty nice visit chimney holly jingle workshop magi polar beard stocking sleigh
#
# Current Energies:
#   6.0117, 6.3828, 6.1094, 6.2734, 6.0703
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 09:03:12
# Iteration: 628/4500 (13.96%)
# Temperature: 0.0262
# Elapsed Time: 1140.96 seconds
# Estimated_remaining_execution_time: 7023.52 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap
#   Solution 2: ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker polar workshop visit sleigh stocking and chimney is beard carol sing jingle relax unwr
#   Solution 3: ornament yuletide of the magi carol grinch nutcracker sleigh polar beard workshop chimney visit naughty nice is unwrap gifts holiday decorations stocking sing jingle relax and eat cheer cheer holly
#   Solution 4: ornament of yuletide cheer is unwrap decorations gifts eat relax sing cheer jingle carol holly sleigh workshop visit the grinch naughty and nice chimney magi nutcracker polar beard stocking holiday
#   Solution 5: ornament yuletide decorations unwrap holly jingle is naughty and nice eat relax cheer chimney stocking cheer gifts of the magi holiday carol sing visit grinch workshop nutcracker sleigh polar beard
#
# Best Energies:
#   5.8086, 5.8320, 5.8438, 5.8828, 5.8984
#
# Current Solutions:
#   Solution 1: ornament yuletide jingle relax unwrap stocking of the magi holiday visit and eat gifts cheer carol sing cheer decorations sleigh workshop grinch chimney nutcracker is naughty nice polar beard holly
#   Solution 2: ornament yuletide grinch cheer unwrap holiday cheer naughty nice is and relax eat decorations sing carol of visit workshop gifts the nutcracker holly jingle sleigh polar beard chimney stocking magi
#   Solution 3: ornament yuletide of the magi carol grinch nutcracker sleigh polar beard workshop chimney visit naughty nice is unwrap gifts holiday decorations stocking sing jingle relax and eat cheer cheer holly
#   Solution 4: ornament yuletide carol the gifts of magi holiday cheer holly unwrap and relax grinch naughty nice polar is beard workshop chimney stocking sing cheer decorations sleigh visit nutcracker eat jingle
#   Solution 5: ornament yuletide the holiday decorations and gifts of cheer cheer is unwrap eat grinch sing carol holly magi visit relax chimney stocking nutcracker naughty nice jingle sleigh polar beard workshop
#
# Current Energies:
#   6.0664, 6.2539, 5.8438, 6.0820, 5.9961
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 09:44:11
# Iteration: 1985/4500 (44.11%)
# Temperature: 0.0181
# Elapsed Time: 3600.02 seconds
# Estimated_remaining_execution_time: 4558.94 seconds
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday unwrap eat relax cheer cheer gifts and decorations visit of the magi grinch carol sing holly jingle sleigh polar workshop chimney beard is naughty nice nutcracker stocking
#   Solution 2: ornament yuletide holiday decorations and gifts unwrap eat relax sing cheer visit workshop naughty nice grinch chimney stocking holly jingle carol magi nutcracker polar beard sleigh is the cheer of
#   Solution 3: ornament yuletide of the magi carol grinch nutcracker sleigh polar beard workshop chimney visit naughty nice is unwrap gifts holiday decorations stocking sing jingle relax and eat cheer cheer holly
#   Solution 4: ornament yuletide decorations unwrap holly jingle is naughty and nice eat relax cheer chimney stocking cheer gifts of the magi holiday carol sing workshop visit grinch nutcracker sleigh polar beard
#   Solution 5: ornament of yuletide cheer is unwrap decorations gifts eat relax sing cheer jingle carol holly sleigh workshop visit the grinch naughty and nice chimney magi nutcracker polar beard stocking holiday
#
# Best Energies:
#   5.8086, 5.8320, 5.8438, 5.8633, 5.8828
#
# Current Solutions:
#   Solution 1: ornament yuletide jingle relax unwrap stocking of the magi holiday visit and eat gifts cheer carol sing cheer decorations holly beard polar is naughty nice sleigh workshop grinch chimney nutcracker
#   Solution 2: ornament yuletide grinch cheer unwrap holiday cheer naughty nice is and eat relax decorations sing carol of holly jingle visit workshop gifts the nutcracker sleigh polar beard chimney stocking magi
#   Solution 3: ornament yuletide of the magi carol grinch nutcracker sleigh polar beard workshop chimney visit naughty nice is unwrap gifts holiday decorations stocking sing jingle relax and eat cheer cheer holly
#   Solution 4: ornament yuletide carol the gifts of magi holiday cheer holly unwrap and relax grinch naughty nice polar is beard workshop chimney stocking sing cheer decorations sleigh visit nutcracker eat jingle
#   Solution 5: ornament yuletide the holiday decorations and gifts of cheer cheer is unwrap eat grinch sing carol holly magi visit relax chimney stocking nutcracker naughty nice jingle sleigh polar beard workshop
#
# Current Energies:
#   6.1055, 6.1641, 5.8438, 6.0820, 5.9961
# ========================================
#
# Exiting.
# Execution time: 3600.0257s

# %%
print(best_solutions)
# Out:
# ['ornament yuletide holiday decorations of the magi gifts grinch naughty nice nutcracker polar workshop visit sleigh stocking and chimney is beard carol sing jingle relax unwrap eat cheer cheer holly', 'ornament yuletide grinch magi carol of cheer holly jingle the nutcracker stocking holiday naughty nice is cheer unwrap and eat relax sing decorations chimney sleigh visit polar beard workshop gifts', 'ornament yuletide of the magi carol grinch nutcracker sleigh polar beard workshop chimney visit naughty nice is unwrap gifts holiday decorations stocking sing jingle relax and eat cheer cheer holly', 'ornament yuletide nutcracker carol the gifts of magi grinch naughty nice visit workshop eat relax chimney sing stocking holly jingle sleigh polar beard cheer cheer holiday decorations and is unwrap', 'ornament yuletide the holiday decorations and gifts of cheer cheer is unwrap eat grin